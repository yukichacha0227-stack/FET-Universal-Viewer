# %% [markdown]
# # FET Universal Viewer - Data Loader Demo
#
# This notebook demonstrates the reusable data-loading part of the desktop application.

# %%
from pathlib import Path

from src.data_loader import merge_measurement_files

sample_files = sorted(Path("sample_data").glob("*.Dat"))
result = merge_measurement_files(sample_files)
df = result.dataframe

result.processed_count, df.shape

# %%
df[["_SourceFile", "Isd", "Vsd", "Vbg"]].head()

# %%
df.groupby("Vbg_R")["Isd"].agg(["count", "min", "max"])

# %% [markdown]
# Run the GUI with:
#
# ```bash
# python FET-Universal-Viewer.py
# ```
